# %%
import pandas as pd

# %% [markdown]
# ### 1) Carregue o arquivo books.csv utilizando o pandas.

# %%
books = pd.read_csv('./books.csv')
books
# Out:
#       Identifier             Edition Statement      Place of Publication  \
# 0            206                           NaN                    London
# 1            216                           NaN  London; Virtue & Yorston
# 2            218                           NaN                    London
# 3            472                           NaN                    London
# 4            480  A new edition, revised, etc.                    London
# ...          ...                           ...                       ...
# 8282     4158088                           NaN                    London
# 8283     4158128                           NaN                     Derby
# 8284     4159563                           NaN                    London
# 8285     4159587                           NaN       Newcastle upon Tyne
# 8286     4160339                           NaN                    London
#
#      Date of Publication                Publisher  \
# ...

# %% [markdown]
# ### 2) Elimine as colunas 'Corporate Author', 'Corporate Contributors', 'Former owner' e 'Engraver'.

# %%
books.drop(columns=['Corporate Author', 'Corporate Contributors', 'Former owner', 'Engraver'])
# Out:
#       Identifier             Edition Statement      Place of Publication  \
# 0            206                           NaN                    London
# 1            216                           NaN  London; Virtue & Yorston
# 2            218                           NaN                    London
# 3            472                           NaN                    London
# 4            480  A new edition, revised, etc.                    London
# ...          ...                           ...                       ...
# 8282     4158088                           NaN                    London
# 8283     4158128                           NaN                     Derby
# 8284     4159563                           NaN                    London
# 8285     4159587                           NaN       Newcastle upon Tyne
# 8286     4160339                           NaN                    London
#
#      Date of Publication                Publisher  \
# ...

# %% [markdown]
# ### 3) Verifique se a coluna 'Identifier' é única e, em caso afirmativo, atribua esta coluna como índice do conjunto de dados.

# %%
books['Identifier'].is_unique
books.set_index('Identifier', inplace = True)

# %% [markdown]
# ### 4) Extrair a data de publicação de modo que somente o ano com quatro posições seja recuperado. Armazene o resultado em uma variável.

# %%
year_publication = books['Date of Publication'].str.extract(r'^(\d{4})', expand=False)
year_publication
# Out:
# Identifier
# 206        1879
# 216        1868
# 218        1869
# 472        1851
# 480        1857
#            ...
# 4158088    1838
# 4158128    1831
# 4159563     NaN
# 4159587    1834
# 4160339    1834
# Name: Date of Publication, Length: 8287, dtype: object

# %% [markdown]
# ### 5) Inclua a nova coluna (armazenada no exercício anterior) no conjunto de dados e, após isso, elimine a coluna 'Date of Publication'.

# %%
books = pd.DataFrame(books)
books.insert(3,"New Date of Publication", year_publication, True)
books.drop(columns=['Date of Publication'])
# Out:
#                        Edition Statement      Place of Publication  \
# Identifier
# 206                                  NaN                    London
# 216                                  NaN  London; Virtue & Yorston
# 218                                  NaN                    London
# 472                                  NaN                    London
# 480         A new edition, revised, etc.                    London
# ...                                  ...                       ...
# 4158088                              NaN                    London
# 4158128                              NaN                     Derby
# 4159563                              NaN                    London
# 4159587                              NaN       Newcastle upon Tyne
# 4160339                              NaN                    London
#
#            New Date of Publication                Publisher  \
# Identifier
# 206                           1879         S. Tinsley & Co.
# ...

# %% [markdown]
# ### 6) Salve o resultado do processamento em um arquivo csv.

# %%
books.to_csv( 'out.csv', encoding='utf-8', index=False)

# %% [markdown]
# ### 7) Realize uma contagem agrupando pela coluna 'New Date of Publication'. Sugestão: Pesquise o método groupby().

# %%
books.groupby(['New Date of Publication'])['New Date of Publication'].count()
# Out:
# New Date of Publication
# 1510      1
# 1540      1
# 1570      1
# 1592      1
# 1602      1
#        ...
# 1898    140
# 1899    132
# 1900      1
# 1911      1
# 1915      1
# Name: New Date of Publication, Length: 254, dtype: int64

# %% [markdown]
# ### 8) Considerando o conteúdo da Unidade 3 visto até o momento elabore 5 (cinco) exemplos que envolvam limpeza e preparação de dados.

# %%
books.isnull()
books.dropna(how='all')
books.dropna(axis=1, how='all')
books.fillna(0)
books.drop_duplicates()
# Out:
#                        Edition Statement      Place of Publication  \
# Identifier
# 206                                  NaN                    London
# 216                                  NaN  London; Virtue & Yorston
# 218                                  NaN                    London
# 472                                  NaN                    London
# 480         A new edition, revised, etc.                    London
# ...                                  ...                       ...
# 4158088                              NaN                    London
# 4158128                              NaN                     Derby
# 4159563                              NaN                    London
# 4159587                              NaN       Newcastle upon Tyne
# 4160339                              NaN                    London
#
#            Date of Publication New Date of Publication  \
# Identifier
# 206                1879 [1878]                    1879
# ...

# %%
import numpy as np

X = np.array([[3,2],
    [4,5],
    [4,7],
    [2,7],
    [6,6],
    [7,7],
    [6,4]])

# %%
import matplotlib.pyplot as plt

labels = range(1, 8)
plt.figure(figsize=(10, 7))
plt.subplots_adjust(bottom=0.1)
plt.scatter(X[:,0],X[:,1], label='True Position')

for label, x, y in zip(labels, X[:, 0], X[:, 1]):
    plt.annotate(
        label,
        xy=(x, y), xytext=(-3, 3),
        textcoords='offset points', ha='right', va='bottom')
plt.show()

# %%
from scipy.cluster.hierarchy import dendrogram, linkage
from matplotlib import pyplot as plt

linked = linkage(X, 'single')

labelList = range(1, 8)

plt.figure(figsize=(10, 7))
dendrogram(linked,
            orientation='top',
            labels=labelList,
            distance_sort='descending')
plt.show()

# %%
import pandas as pd
data = pd.DataFrame(X, columns=['a', 'b'])

# %%
import scipy
from scipy.spatial.distance import squareform, pdist
dist = pd.DataFrame(squareform(pdist(data[['a', 'b']]), 'euclidean'), columns=data.index.values, index=data.index.values)
dist
# Out:
#           0         1         2         3         4         5         6
# 0  0.000000  3.162278  5.099020  5.099020  5.000000  6.403124  3.605551
# 1  3.162278  0.000000  2.000000  2.828427  2.236068  3.605551  2.236068
# 2  5.099020  2.000000  0.000000  2.000000  2.236068  3.000000  3.605551
# 3  5.099020  2.828427  2.000000  0.000000  4.123106  5.000000  5.000000
# 4  5.000000  2.236068  2.236068  4.123106  0.000000  1.414214  2.000000
# 5  6.403124  3.605551  3.000000  5.000000  1.414214  0.000000  3.162278
# 6  3.605551  2.236068  3.605551  5.000000  2.000000  3.162278  0.000000
